# %%
import os

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv
import pickle

from tqdm import tqdm
from homography_transform import Homography_Transform, Homography_Transform_From_Matrix

# %%
DATA_PATH = os.getcwd() + '/Data/'

# %% [markdown]
# ---
# # Perform Homography on Masks ONLY

# %%
ids = next(os.walk(f"{DATA_PATH}predicted_padded"))[2]
print("No. of images = ", len(ids))
# Out:
# No. of images =  68

# %%
infile = open(f"{DATA_PATH}F_series_drop_list.pickle","rb")
drop_list = pickle.load(infile)
infile.close()

# %%
img_list=[]
for i in ids[29:]:
    if not i in drop_list:
        img_list.append(i)

# %%
src = cv.imread(f'{DATA_PATH}predicted_padded/{img_list[1]}',0)
dst = cv.imread(f'{DATA_PATH}predicted_padded/{img_list[0]}',0)
#No transformation on the first image
cv.imwrite(f'{DATA_PATH}predicted_corrected/{img_list[0]}',dst)

#Do the transformation on the second image
warped = Homography_Transform(src,dst,scale=3)
cv.imwrite(f'{DATA_PATH}predicted_corrected/{img_list[1]}',warped)

#Do transformation on the rest
for i in range(2,len(img_list)):
    src = cv.imread(f'{DATA_PATH}predicted_padded/{img_list[i]}',0)
    dst = cv.imread(f'{DATA_PATH}predicted_corrected/{img_list[i-1]}',0)
    warped = Homography_Transform(src,dst,scale=3)
    cv.imwrite(f'{DATA_PATH}predicted_corrected/{img_list[i]}',warped)
# Out:
# WARNING: The input images are resized to 800x600 for ASIFT.
#          But the results will be normalized to the original image size.
#
# Computing keypoints on the two images...
# 18013 ASIFT keypoints are detected.
# 17404 ASIFT keypoints are detected.
# Keypoints computation accomplished in 16 seconds.
# Matching the keypoints...
# The two images match! 2785 matchings are identified. log(nfa)=-4695.1.
# Keypoints matching accomplished in 6 seconds.
# WARNING: The input images are resized to 800x600 for ASIFT.
#          But the results will be normalized to the original image size.
#
# Computing keypoints on the two images...
# 17440 ASIFT keypoints are detected.
# 17976 ASIFT keypoints are detected.
# Keypoints computation accomplished in 16 seconds.
# Matching the keypoints...
# The two images match! 3666 matchings are identified. log(nfa)=-6299.4.
# Keypoints matching accomplished in 6 seconds.
# WARNING: The input images are resized to 800x600 for ASIFT.
#          But the results will be normalized to the original image size.
#
# Computing keypoints on the two images...
# 17276 ASIFT keypoints are detected.
# 18057 ASIFT keypoints are detected.
# Keypoints computation accomplished in 16 seconds.
# Matching the keypoints...
# The two images match! 2644 matchings are identified. log(nfa)=-4298.81.
# Keypoints matching accomplished in 6 seconds.
# WARNING: The input images are resized to 800x600 for ASIFT.
#          But the results will be normalized to the original image size.
#
# Computing keypoints on the two images...
# 17954 ASIFT keypoints are detected.
# 18254 ASIFT keypoints are detected.
# Keypoints computation accomplished in 16 seconds.
# Matching the keypoints...
# The two images match! 3390 matchings are identified. log(nfa)=-5586.69.
# Keypoints matching accomplished in 7 seconds.
# WARNING: The input images are resized to 800x600 for ASIFT.
#          But the results will be normalized to the original image size.
#
# Computing keypoints on the two images...
# 17554 ASIFT keypoints are detected.
# 18276 ASIFT keypoints are detected.
# Keypoints computation accomplished in 16 seconds.
# Matching the keypoints...
# The two images match! 5227 matchings are identified. log(nfa)=-9801.21.
# Keypoints matching accomplished in 8 seconds.
# WARNING: The input images are resized to 800x600 for ASIFT.
#          But the results will be normalized to the original image size.
#
# Computing keypoints on the two images...
# 17460 ASIFT keypoints are detected.
# 18002 ASIFT keypoints are detected.
# Keypoints computation accomplished in 16 seconds.
# Matching the keypoints...
# The two images match! 2812 matchings are identified. log(nfa)=-4542.18.
# Keypoints matching accomplished in 6 seconds.
# WARNING: The input images are resized to 800x600 for ASIFT.
#          But the results will be normalized to the original image size.
#
# Computing keypoints on the two images...
# 17608 ASIFT keypoints are detected.
# 17685 ASIFT keypoints are detected.
# Keypoints computation accomplished in 15 seconds.
# Matching the keypoints...
# The two images match! 3343 matchings are identified. log(nfa)=-5840.27.
# Keypoints matching accomplished in 7 seconds.
# WARNING: The input images are resized to 800x600 for ASIFT.
#          But the results will be normalized to the original image size.
#
# Computing keypoints on the two images...
# 17853 ASIFT keypoints are detected.
# 17761 ASIFT keypoints are detected.
# Keypoints computation accomplished in 15 seconds.
# Matching the keypoints...
# The two images match! 3352 matchings are identified. log(nfa)=-5800.85.
# Keypoints matching accomplished in 7 seconds.
# WARNING: The input images are resized to 800x600 for ASIFT.
#          But the results will be normalized to the original image size.
#
# Computing keypoints on the two images...
# 17875 ASIFT keypoints are detected.
# 17758 ASIFT keypoints are detected.
# Keypoints computation accomplished in 16 seconds.
# Matching the keypoints...
# The two images match! 2557 matchings are identified. log(nfa)=-4306.99.
# Keypoints matching accomplished in 6 seconds.
# WARNING: The input images are resized to 800x600 for ASIFT.
#          But the results will be normalized to the original image size.
#
# Computing keypoints on the two images...
# 17685 ASIFT keypoints are detected.
# 18001 ASIFT keypoints are detected.
# Keypoints computation accomplished in 16 seconds.
# Matching the keypoints...
# The two images match! 3382 matchings are identified. log(nfa)=-5933.99.
# Keypoints matching accomplished in 6 seconds.
# WARNING: The input images are resized to 800x600 for ASIFT.
#          But the results will be normalized to the original image size.
#
# Computing keypoints on the two images...
# 17904 ASIFT keypoints are detected.
# 17810 ASIFT keypoints are detected.
# Keypoints computation accomplished in 16 seconds.
# Matching the keypoints...
# The two images match! 3870 matchings are identified. log(nfa)=-6821.81.
# Keypoints matching accomplished in 7 seconds.
# WARNING: The input images are resized to 800x600 for ASIFT.
#          But the results will be normalized to the original image size.
#
# Computing keypoints on the two images...
# 17729 ASIFT keypoints are detected.
# 18135 ASIFT keypoints are detected.
# Keypoints computation accomplished in 15 seconds.
# Matching the keypoints...
# The two images match! 4119 matchings are identified. log(nfa)=-7107.67.
# Keypoints matching accomplished in 7 seconds.
# WARNING: The input images are resized to 800x600 for ASIFT.
#          But the results will be normalized to the original image size.
#
# Computing keypoints on the two images...
# 17758 ASIFT keypoints are detected.
# 17700 ASIFT keypoints are detected.
# Keypoints computation accomplished in 16 seconds.
# Matching the keypoints...
# The two images match! 3599 matchings are identified. log(nfa)=-6127.48.
# Keypoints matching accomplished in 6 seconds.
# WARNING: The input images are resized to 800x600 for ASIFT.
#          But the results will be normalized to the original image size.
#
# Computing keypoints on the two images...
# 17696 ASIFT keypoints are detected.
# 17986 ASIFT keypoints are detected.
# Keypoints computation accomplished in 16 seconds.
# Matching the keypoints...
# The two images match! 2653 matchings are identified. log(nfa)=-4593.01.
# Keypoints matching accomplished in 6 seconds.
# WARNING: The input images are resized to 800x600 for ASIFT.
#          But the results will be normalized to the original image size.
#
# Computing keypoints on the two images...
# 18338 ASIFT keypoints are detected.
# 17702 ASIFT keypoints are detected.
# Keypoints computation accomplished in 16 seconds.
# Matching the keypoints...
# The two images match! 3459 matchings are identified. log(nfa)=-5951.94.
# Keypoints matching accomplished in 7 seconds.
# WARNING: The input images are resized to 800x600 for ASIFT.
#          But the results will be normalized to the original image size.
#
# Computing keypoints on the two images...
# 18050 ASIFT keypoints are detected.
# 18354 ASIFT keypoints are detected.
# Keypoints computation accomplished in 15 seconds.
# Matching the keypoints...
# The two images match! 4092 matchings are identified. log(nfa)=-7081.98.
# Keypoints matching accomplished in 8 seconds.
# WARNING: The input images are resized to 800x600 for ASIFT.
#          But the results will be normalized to the original image size.
#
# Computing keypoints on the two images...
# 18429 ASIFT keypoints are detected.
# 17678 ASIFT keypoints are detected.
# Keypoints computation accomplished in 16 seconds.
# Matching the keypoints...
# The two images match! 3553 matchings are identified. log(nfa)=-6345.38.
# Keypoints matching accomplished in 7 seconds.
# WARNING: The input images are resized to 800x600 for ASIFT.
#          But the results will be normalized to the original image size.
#
# Computing keypoints on the two images...
# 18671 ASIFT keypoints are detected.
# 18310 ASIFT keypoints are detected.
# Keypoints computation accomplished in 16 seconds.
# Matching the keypoints...
# The two images match! 3321 matchings are identified. log(nfa)=-5706.43.
# Keypoints matching accomplished in 7 seconds.
# WARNING: The input images are resized to 800x600 for ASIFT.
#          But the results will be normalized to the original image size.
#
# Computing keypoints on the two images...
# 17251 ASIFT keypoints are detected.
# 18276 ASIFT keypoints are detected.
# Keypoints computation accomplished in 15 seconds.
# Matching the keypoints...
# The two images match! 1452 matchings are identified. log(nfa)=-2356.89.
# Keypoints matching accomplished in 6 seconds.
# WARNING: The input images are resized to 800x600 for ASIFT.
#          But the results will be normalized to the original image size.
#
# Computing keypoints on the two images...
# 17871 ASIFT keypoints are detected.
# 17363 ASIFT keypoints are detected.
# Keypoints computation accomplished in 16 seconds.
# Matching the keypoints...
# The two images match! 2798 matchings are identified. log(nfa)=-4440.79.
# Keypoints matching accomplished in 6 seconds.
# WARNING: The input images are resized to 800x600 for ASIFT.
#          But the results will be normalized to the original image size.
#
# Computing keypoints on the two images...
# 17736 ASIFT keypoints are detected.
# 17776 ASIFT keypoints are detected.
# Keypoints computation accomplished in 16 seconds.
# Matching the keypoints...
# The two images match! 3858 matchings are identified. log(nfa)=-6745.86.
# Keypoints matching accomplished in 7 seconds.
# WARNING: The input images are resized to 800x600 for ASIFT.
#          But the results will be normalized to the original image size.
#
# Computing keypoints on the two images...
# 17512 ASIFT keypoints are detected.
# 17737 ASIFT keypoints are detected.
# Keypoints computation accomplished in 16 seconds.
# Matching the keypoints...
# The two images match! 2897 matchings are identified. log(nfa)=-4890.54.
# Keypoints matching accomplished in 6 seconds.
# WARNING: The input images are resized to 800x600 for ASIFT.
#          But the results will be normalized to the original image size.
#
# Computing keypoints on the two images...
# 17162 ASIFT keypoints are detected.
# 17582 ASIFT keypoints are detected.
# Keypoints computation accomplished in 16 seconds.
# Matching the keypoints...
# The two images match! 2460 matchings are identified. log(nfa)=-4089.68.
# Keypoints matching accomplished in 6 seconds.
# WARNING: The input images are resized to 800x600 for ASIFT.
#          But the results will be normalized to the original image size.
#
# Computing keypoints on the two images...
# 17401 ASIFT keypoints are detected.
# 17751 ASIFT keypoints are detected.
# Keypoints computation accomplished in 16 seconds.
# Matching the keypoints...
# The two images match! 2949 matchings are identified. log(nfa)=-4760.68.
# Keypoints matching accomplished in 7 seconds.

# %% [markdown]
# ---
# # Perform Homography on Mask AND Color images AND ROI

# %%
ids = next(os.walk(f"{DATA_PATH}predicted_padded"))[2]
print("No. of images = ", len(ids))
# Out:
# No. of images =  68

# %%
infile = open(f"{DATA_PATH}F_series_drop_list.pickle","rb")
drop_list = pickle.load(infile)
infile.close()

# %%
img_list=[]
for i in ids[29:]:
    if not i in drop_list:
        img_list.append(i)

# %%
src = cv.imread(f'{DATA_PATH}predicted_padded/{img_list[1]}',0)
src_color = cv.imread(f'{DATA_PATH}predicted_padded/raw_color/{img_list[1]}')
src_roi = cv.imread(f'{DATA_PATH}predicted_padded/roi/{img_list[1]}')
dst = cv.imread(f'{DATA_PATH}predicted_padded/{img_list[0]}',0)
dst_color = cv.imread(f'{DATA_PATH}predicted_padded/raw_color/{img_list[0]}')
dst_roi = cv.imread(f'{DATA_PATH}predicted_padded/roi/{img_list[0]}')
#No transformation on the first image
cv.imwrite(f'{DATA_PATH}predicted_corrected/{img_list[0]}',dst)
cv.imwrite(f'{DATA_PATH}predicted_corrected/raw_color/{img_list[0]}',dst_color)
cv.imwrite(f'{DATA_PATH}predicted_corrected/roi/{img_list[0]}',dst_roi)

#Do the transformation on the second image
warped,H = Homography_Transform(src,dst,scale=3,return_matrix=True)
warped_color = Homography_Transform_From_Matrix(src_color,dst,H=H)
warped_roi = Homography_Transform_From_Matrix(src_roi,dst,H=H,border_value=(0,0,0))
_,warped_roi = cv.threshold(warped_roi, 128, 255, cv.THRESH_BINARY)
cv.imwrite(f'{DATA_PATH}predicted_corrected/{img_list[1]}',warped)
cv.imwrite(f'{DATA_PATH}predicted_corrected/raw_color/{img_list[1]}',warped_color)
cv.imwrite(f'{DATA_PATH}predicted_corrected/roi/{img_list[1]}',warped_roi)

#Do transformation on the rest
for i in range(2,len(img_list)):
    src = cv.imread(f'{DATA_PATH}predicted_padded/{img_list[i]}',0)
    src_color = cv.imread(f'{DATA_PATH}predicted_padded/raw_color/{img_list[i]}')
    src_roi = cv.imread(f'{DATA_PATH}predicted_padded/roi/{img_list[i]}')
    dst = cv.imread(f'{DATA_PATH}predicted_corrected/{img_list[i-1]}',0)
    warped,H = Homography_Transform(src,dst,scale=3,return_matrix=True)
    warped_color = Homography_Transform_From_Matrix(src_color,dst,H=H)
    warped_roi = Homography_Transform_From_Matrix(src_roi,dst,H=H,border_value=(0,0,0))
    _,warped_roi = cv.threshold(warped_roi, 128, 255, cv.THRESH_BINARY)
    cv.imwrite(f'{DATA_PATH}predicted_corrected/{img_list[i]}',warped)
    cv.imwrite(f'{DATA_PATH}predicted_corrected/raw_color/{img_list[i]}',warped_color)
    cv.imwrite(f'{DATA_PATH}predicted_corrected/roi/{img_list[i]}',warped_roi)
# Out:
# WARNING: The input images are resized to 800x600 for ASIFT.
#          But the results will be normalized to the original image size.
#
# Computing keypoints on the two images...
# 18013 ASIFT keypoints are detected.
# 17404 ASIFT keypoints are detected.
# Keypoints computation accomplished in 16 seconds.
# Matching the keypoints...
# The two images match! 2784 matchings are identified. log(nfa)=-4667.67.
# Keypoints matching accomplished in 7 seconds.
# WARNING: The input images are resized to 800x600 for ASIFT.
#          But the results will be normalized to the original image size.
#
# Computing keypoints on the two images...
# 17440 ASIFT keypoints are detected.
# 18073 ASIFT keypoints are detected.
# Keypoints computation accomplished in 15 seconds.
# Matching the keypoints...
# The two images match! 3674 matchings are identified. log(nfa)=-6339.01.
# Keypoints matching accomplished in 7 seconds.
# WARNING: The input images are resized to 800x600 for ASIFT.
#          But the results will be normalized to the original image size.
#
# Computing keypoints on the two images...
# 17276 ASIFT keypoints are detected.
# 17802 ASIFT keypoints are detected.
# Keypoints computation accomplished in 16 seconds.
# Matching the keypoints...
# The two images match! 2703 matchings are identified. log(nfa)=-4475.71.
# Keypoints matching accomplished in 6 seconds.
# WARNING: The input images are resized to 800x600 for ASIFT.
#          But the results will be normalized to the original image size.
#
# Computing keypoints on the two images...
# 17954 ASIFT keypoints are detected.
# 17942 ASIFT keypoints are detected.
# Keypoints computation accomplished in 16 seconds.
# Matching the keypoints...
# The two images match! 3399 matchings are identified. log(nfa)=-5540.95.
# Keypoints matching accomplished in 7 seconds.
# WARNING: The input images are resized to 800x600 for ASIFT.
#          But the results will be normalized to the original image size.
#
# Computing keypoints on the two images...
# 17554 ASIFT keypoints are detected.
# 17792 ASIFT keypoints are detected.
# Keypoints computation accomplished in 16 seconds.
# Matching the keypoints...
# The two images match! 5112 matchings are identified. log(nfa)=-9520.17.
# Keypoints matching accomplished in 7 seconds.
# WARNING: The input images are resized to 800x600 for ASIFT.
#          But the results will be normalized to the original image size.
#
# Computing keypoints on the two images...
# 17460 ASIFT keypoints are detected.
# 17637 ASIFT keypoints are detected.
# Keypoints computation accomplished in 15 seconds.
# Matching the keypoints...
# The two images match! 2883 matchings are identified. log(nfa)=-4670.39.
# Keypoints matching accomplished in 6 seconds.
# WARNING: The input images are resized to 800x600 for ASIFT.
#          But the results will be normalized to the original image size.
#
# Computing keypoints on the two images...
# 17608 ASIFT keypoints are detected.
# 17519 ASIFT keypoints are detected.
# Keypoints computation accomplished in 15 seconds.
# Matching the keypoints...
# The two images match! 3231 matchings are identified. log(nfa)=-5580.95.
# Keypoints matching accomplished in 7 seconds.
# WARNING: The input images are resized to 800x600 for ASIFT.
#          But the results will be normalized to the original image size.
#
# Computing keypoints on the two images...
# 17853 ASIFT keypoints are detected.
# 17582 ASIFT keypoints are detected.
# Keypoints computation accomplished in 16 seconds.
# Matching the keypoints...
# The two images match! 3173 matchings are identified. log(nfa)=-5501.89.
# Keypoints matching accomplished in 6 seconds.
# WARNING: The input images are resized to 800x600 for ASIFT.
#          But the results will be normalized to the original image size.
#
# Computing keypoints on the two images...
# 17875 ASIFT keypoints are detected.
# 17715 ASIFT keypoints are detected.
# Keypoints computation accomplished in 16 seconds.
# Matching the keypoints...
# The two images match! 2313 matchings are identified. log(nfa)=-3810.26.
# Keypoints matching accomplished in 6 seconds.
# WARNING: The input images are resized to 800x600 for ASIFT.
#          But the results will be normalized to the original image size.
#
# Computing keypoints on the two images...
# 17685 ASIFT keypoints are detected.
# 17911 ASIFT keypoints are detected.
# Keypoints computation accomplished in 16 seconds.
# Matching the keypoints...
# The two images match! 3278 matchings are identified. log(nfa)=-5618.56.
# Keypoints matching accomplished in 7 seconds.
# WARNING: The input images are resized to 800x600 for ASIFT.
#          But the results will be normalized to the original image size.
#
# Computing keypoints on the two images...
# 17904 ASIFT keypoints are detected.
# 17504 ASIFT keypoints are detected.
# Keypoints computation accomplished in 16 seconds.
# Matching the keypoints...
# The two images match! 3782 matchings are identified. log(nfa)=-6463.42.
# Keypoints matching accomplished in 7 seconds.
# WARNING: The input images are resized to 800x600 for ASIFT.
#          But the results will be normalized to the original image size.
#
# Computing keypoints on the two images...
# 17729 ASIFT keypoints are detected.
# 17825 ASIFT keypoints are detected.
# Keypoints computation accomplished in 15 seconds.
# Matching the keypoints...
# The two images match! 3830 matchings are identified. log(nfa)=-6569.09.
# Keypoints matching accomplished in 7 seconds.
# WARNING: The input images are resized to 800x600 for ASIFT.
#          But the results will be normalized to the original image size.
#
# Computing keypoints on the two images...
# 17758 ASIFT keypoints are detected.
# 17397 ASIFT keypoints are detected.
# Keypoints computation accomplished in 16 seconds.
# Matching the keypoints...
# The two images match! 3498 matchings are identified. log(nfa)=-6061.99.
# Keypoints matching accomplished in 7 seconds.
# WARNING: The input images are resized to 800x600 for ASIFT.
#          But the results will be normalized to the original image size.
#
# Computing keypoints on the two images...
# 17696 ASIFT keypoints are detected.
# 17808 ASIFT keypoints are detected.
# Keypoints computation accomplished in 16 seconds.
# Matching the keypoints...
# The two images match! 2767 matchings are identified. log(nfa)=-4891.16.
# Keypoints matching accomplished in 6 seconds.
# WARNING: The input images are resized to 800x600 for ASIFT.
#          But the results will be normalized to the original image size.
#
# Computing keypoints on the two images...
# 18338 ASIFT keypoints are detected.
# 17632 ASIFT keypoints are detected.
# Keypoints computation accomplished in 15 seconds.
# Matching the keypoints...
# The two images match! 3320 matchings are identified. log(nfa)=-5550.89.
# Keypoints matching accomplished in 7 seconds.
# WARNING: The input images are resized to 800x600 for ASIFT.
#          But the results will be normalized to the original image size.
#
# Computing keypoints on the two images...
# 18050 ASIFT keypoints are detected.
# 18192 ASIFT keypoints are detected.
# Keypoints computation accomplished in 16 seconds.
# Matching the keypoints...
# The two images match! 3759 matchings are identified. log(nfa)=-6688.02.
# Keypoints matching accomplished in 7 seconds.
# WARNING: The input images are resized to 800x600 for ASIFT.
#          But the results will be normalized to the original image size.
#
# Computing keypoints on the two images...
# 18429 ASIFT keypoints are detected.
# 17731 ASIFT keypoints are detected.
# Keypoints computation accomplished in 16 seconds.
# Matching the keypoints...
# The two images match! 3455 matchings are identified. log(nfa)=-6249.2.
# Keypoints matching accomplished in 7 seconds.
# WARNING: The input images are resized to 800x600 for ASIFT.
#          But the results will be normalized to the original image size.
#
# Computing keypoints on the two images...
# 18671 ASIFT keypoints are detected.
# 17914 ASIFT keypoints are detected.
# Keypoints computation accomplished in 16 seconds.
# Matching the keypoints...
# The two images match! 3178 matchings are identified. log(nfa)=-5504.02.
# Keypoints matching accomplished in 7 seconds.
# WARNING: The input images are resized to 800x600 for ASIFT.
#          But the results will be normalized to the original image size.
#
# Computing keypoints on the two images...
# 17251 ASIFT keypoints are detected.
# 17962 ASIFT keypoints are detected.
# Keypoints computation accomplished in 16 seconds.
# Matching the keypoints...
# The two images match! 1518 matchings are identified. log(nfa)=-2322.72.
# Keypoints matching accomplished in 6 seconds.
# WARNING: The input images are resized to 800x600 for ASIFT.
#          But the results will be normalized to the original image size.
#
# Computing keypoints on the two images...
# 17871 ASIFT keypoints are detected.
# 17434 ASIFT keypoints are detected.
# Keypoints computation accomplished in 16 seconds.
# Matching the keypoints...
# The two images match! 2674 matchings are identified. log(nfa)=-4317.64.
# Keypoints matching accomplished in 6 seconds.
# WARNING: The input images are resized to 800x600 for ASIFT.
#          But the results will be normalized to the original image size.
#
# Computing keypoints on the two images...
# 17736 ASIFT keypoints are detected.
# 17904 ASIFT keypoints are detected.
# Keypoints computation accomplished in 16 seconds.
# Matching the keypoints...
# The two images match! 3764 matchings are identified. log(nfa)=-6525.16.
# Keypoints matching accomplished in 7 seconds.
# WARNING: The input images are resized to 800x600 for ASIFT.
#          But the results will be normalized to the original image size.
#
# Computing keypoints on the two images...
# 17512 ASIFT keypoints are detected.
# 17829 ASIFT keypoints are detected.
# Keypoints computation accomplished in 15 seconds.
# Matching the keypoints...
# The two images match! 2841 matchings are identified. log(nfa)=-5029.83.
# Keypoints matching accomplished in 7 seconds.
# WARNING: The input images are resized to 800x600 for ASIFT.
#          But the results will be normalized to the original image size.
#
# Computing keypoints on the two images...
# 17162 ASIFT keypoints are detected.
# 17597 ASIFT keypoints are detected.
# Keypoints computation accomplished in 15 seconds.
# Matching the keypoints...
# The two images match! 2528 matchings are identified. log(nfa)=-4306.57.
# Keypoints matching accomplished in 6 seconds.
# WARNING: The input images are resized to 800x600 for ASIFT.
#          But the results will be normalized to the original image size.
#
# Computing keypoints on the two images...
# 17401 ASIFT keypoints are detected.
# 17190 ASIFT keypoints are detected.
# Keypoints computation accomplished in 16 seconds.
# Matching the keypoints...
# The two images match! 2843 matchings are identified. log(nfa)=-4732.21.
# Keypoints matching accomplished in 6 seconds.
